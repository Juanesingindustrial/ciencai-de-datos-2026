# %%
##Seleccion de datos

# %% [markdown]
# ##Seleccion de datos
# Agenda
# 1. Insercion de bloques de texto
# 2. Incersion de titulos
# 3.Trabajndo con el bloque de codigo

# %%
print("Hola mundo")
# Out:
# Hola mundo
